# %%
import pandas as pd

# %%
import seaborn as sns

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
irecrime=pd.read_csv("D:\MS\Project\PROJ_IRE\IRE_CRIM.csv")

# %%
irecrime.head(5)
# Out:
#      id           Station                       Divisions       x       y  \
# 0   201     Pearse Street   D.M.R. South Central Division  316180  234222
# 1  2016          Tallaght        D.M.R. Southern Division  308900  227492
# 2  2031    Blanchardstown         D.M.R. Western Division  307764  238947
# 3  2032      Store Street   D.M.R. North Central Division  316435  234757
# 4  2035  Bridewell Dublin   D.M.R. North Central Division  314987  234346
#
#    Attempts or threats to murder, assaults, harassments and related offences 2013  \
# 0                                                481
# 1                                                279
# 2                                                188
# 3                                                304
# 4                                                119
#
#    Attempts or threats to murder, assaults, harassments and related offences 2014  \
# 0                                                520
# ...

# %%
irecrime.plot(x="Station", y=["Attempts or threats to murder, assaults, harassments and related offences 2013", "Attempts or threats to murder, assaults, harassments and related offences 2014", "Attempts or threats to murder, assaults, harassments and related offences 2015","Attempts or threats to murder, assaults, harassments and related offences 2016","Attempts or threats to murder, assaults, harassments and related offences 2017","Attempts or threats to murder, assaults, harassments and related offences 2018"], kind="bar")

# %%
irecrime.plot(x="Station", y=["Dangerous or negligent acts 2013", "Dangerous or negligent acts 2014", "Dangerous or negligent acts 2015","Dangerous or negligent acts 2016*","Dangerous or negligent acts 2017","Dangerous or negligent acts 2018"], kind="barh")

# %%
irecrime.plot(x="Station", y=["Kidnapping and related offences 2013", "Kidnapping and related offences 2014", "Kidnapping and related offences 2015","Kidnapping and related offences 2016*","Kidnapping and related offences 2017","Kidnapping and related offences 2018"], kind="barh")

# %%
irecrime.plot(x="Station", y=["Robbery, extortion and hijacking offences 2013", "Robbery, extortion and hijacking offences 2014", "Robbery, extortion and hijacking offences 2015","Robbery, extortion and hijacking offences 2016*","Robbery, extortion and hijacking offences 2017","Robbery, extortion and hijacking offences 2018"], kind="barh")

# %%
irecrime.plot(x="Station", y=["Burglary and related offences 2013", "Burglary and related offences 2014", "Burglary and related offences 2015","Burglary and related offences 2016*","Burglary and related offences 2017","Burglary and related offences 2018"], kind="bar")

# %%
irecrime.plot(x="Station", y=["Theft and related offences 2013", "Theft and related offences 2014", "Theft and related offences 2015","Theft and related offences 2016*","Theft and related offences 2017","Theft and related offences 2018"], kind="barh")

# %%
irecrime.plot(x="Station", y=["Fraud, deception and related offences 2013", "Fraud, deception and related offences 2014", "Fraud, deception and related offences 2015","Fraud, deception and related offences 2016*","Fraud, deception and related offences 2017","Fraud, deception and related offences 2018"], kind="bar")

# %%
irecrime.plot(x="Station", y=["Controlled drug offences 2013", "Controlled drug offences 2014", "Controlled drug offences 2015","Controlled drug offences 2016*","Controlled drug offences 2017","Controlled drug offences 2018"], kind="bar")

# %%
irecrime.plot(x="Station", y=["Offences against government, justice procedures and organisation of crime 2013", "Offences against government, justice procedures and organisation of crime 2014", "Offences against government, justice procedures and organisation of crime 2015","Offences against government, justice procedures and organisation of crime 2016*","Offences against government, justice procedures and organisation of crime 2017","Offences against government, justice procedures and organisation of crime 2018"], kind="bar")
