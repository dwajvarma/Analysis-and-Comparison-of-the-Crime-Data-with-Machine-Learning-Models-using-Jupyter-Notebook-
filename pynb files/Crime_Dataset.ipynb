# %%
import pandas as pd

# %%
import seaborn as sns

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import datetime as dt

# %%
crime=pd.read_csv("D:\MS\Project\PYthon\Crimes1.csv")
cm=pd.read_csv("D:\MS\Project\PYthon\Crimes1.csv")

# %%
crime.head(5)
# Out:
#          ID Case Number             Date                   Block  IUCR  \
# 0  10000092    HY189866  3/18/2015 19:44         047XX W OHIO ST  041A
# 1  10000094    HY190059  3/18/2015 23:00  066XX S MARSHFIELD AVE  4625
# 2  10000095    HY190052  3/18/2015 22:45   044XX S LAKE PARK AVE   486
# 3  10000096    HY190054  3/18/2015 22:30    051XX S MICHIGAN AVE   460
# 4  10000097    HY189976  3/18/2015 21:00        047XX W ADAMS ST  031A
#
#     Primary Type              Description Location Description  Arrest  \
# 0        BATTERY      AGGRAVATED: HANDGUN               STREET   False
# 1  OTHER OFFENSE         PAROLE VIOLATION               STREET    True
# 2        BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 3        BATTERY                   SIMPLE            APARTMENT   False
# 4        ROBBERY           ARMED: HANDGUN             SIDEWALK   False
#
#    Domestic              ...                Ward  Community Area  FBI Code  \
# ...

# %%
crime.describe()
# Out:
#                  ID          Beat      District          Ward  Community Area  \
# count  1.048575e+06  1.048575e+06  1.048574e+06  1.017424e+06    1.017304e+06
# mean   8.825080e+06  1.160223e+03  1.123726e+01  2.294357e+01    3.703432e+01
# std    3.364824e+06  6.979983e+02  6.941977e+00  1.395276e+01    2.139945e+01
# min    6.340000e+02  1.110000e+02  1.000000e+00  1.000000e+00    0.000000e+00
# 25%    7.513384e+06  6.130000e+02  6.000000e+00  1.000000e+01    2.300000e+01
# 50%    1.047795e+07  1.032000e+03  1.000000e+01  2.300000e+01    3.200000e+01
# 75%    1.097933e+07  1.722000e+03  1.700000e+01  3.400000e+01    5.600000e+01
# max    1.137408e+07  2.535000e+03  3.100000e+01  5.000000e+01    7.700000e+01
#
#        X Coordinate  Y Coordinate          Year      Latitude     Longitude
# count  1.020228e+06  1.020228e+06  1.048575e+06  1.020228e+06  1.020228e+06
# mean   1.164579e+06  1.886131e+06  2.013076e+03  4.184314e+01 -8.767155e+01
# ...

# %%
crime=crime[(crime['Year']==2015)|(crime['Year']==2016)|(crime['Year']==2017)|(crime['Year']==2018)]
crime.drop([ 'Case Number', 'X Coordinate', 'Y Coordinate', 'Beat','Ward','Community Area','Latitude','Longitude','District'], inplace=True, axis=1)
crime.describe()
# Out:
#                  ID           Year
# count  7.794390e+05  779439.000000
# mean   1.071293e+07    2016.344785
# std    4.665099e+05       1.028323
# min    2.186400e+04    2015.000000
# 25%    1.035965e+07    2015.000000
# 50%    1.071731e+07    2016.000000
# 75%    1.108944e+07    2017.000000
# max    1.137408e+07    2018.000000

# %%
sns.countplot(x='Year',data=crime) #CRIMES EACH YEAR
plt.ylabel('No of crimes')
plt.show()

# %%
from datetime import datetime

# %%
#Convert date in the data set to an interpretative format that python can understand.
crime['Date'] = pd.to_datetime(crime['Date'],format='%m/%d/%Y %H:%M')

# %%
# Creating month column
import calendar
crime['Month']=(crime['Date'].dt.month).apply(lambda x: calendar.month_abbr[x])
crime.head(4)
# Out:
#          ID                Date                   Block  IUCR   Primary Type  \
# 0  10000092 2015-03-18 19:44:00         047XX W OHIO ST  041A        BATTERY
# 1  10000094 2015-03-18 23:00:00  066XX S MARSHFIELD AVE  4625  OTHER OFFENSE
# 2  10000095 2015-03-18 22:45:00   044XX S LAKE PARK AVE   486        BATTERY
# 3  10000096 2015-03-18 22:30:00    051XX S MICHIGAN AVE   460        BATTERY
#
#                Description Location Description  Arrest  Domestic FBI Code  \
# 0      AGGRAVATED: HANDGUN               STREET   False     False      04B
# 1         PAROLE VIOLATION               STREET    True     False       26
# 2  DOMESTIC BATTERY SIMPLE            APARTMENT   False      True      08B
# 3                   SIMPLE            APARTMENT   False     False      08B
#
#    Year       Updated On                       Location Month
# 0  2015  2/10/2018 15:50  (41.891398861, -87.744384567)   Mar
# 1  2015  2/10/2018 15:50  (41.773371528, -87.665319468)   Mar
# ...

# %%
crime['Month'] = pd.Categorical(crime['Month'] , categories=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'], ordered=True)

# %%
import numpy as np
months=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
crime.groupby('Month')['ID'].count().plot(marker='o')
plt.xticks(np.arange(12),months)
plt.ylabel('No of Crimes')
plt.show()

# %%
crime.groupby(['Month','Year'])['ID'].count().unstack().plot(kind='bar')
plt.ylabel('No of crimes')
plt.show()

# %%
crime["Weekday"] = crime['Date'].dt.weekday_name
crime['Weekday'] = pd.Categorical(crime['Weekday'],categories=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday', 'Sunday'], ordered=True)
crime.head()
# Out:
#          ID                Date                   Block  IUCR   Primary Type  \
# 0  10000092 2015-03-18 19:44:00         047XX W OHIO ST  041A        BATTERY
# 1  10000094 2015-03-18 23:00:00  066XX S MARSHFIELD AVE  4625  OTHER OFFENSE
# 2  10000095 2015-03-18 22:45:00   044XX S LAKE PARK AVE   486        BATTERY
# 3  10000096 2015-03-18 22:30:00    051XX S MICHIGAN AVE   460        BATTERY
# 4  10000097 2015-03-18 21:00:00        047XX W ADAMS ST  031A        ROBBERY
#
#                Description Location Description  Arrest  Domestic FBI Code  \
# 0      AGGRAVATED: HANDGUN               STREET   False     False      04B
# 1         PAROLE VIOLATION               STREET    True     False       26
# 2  DOMESTIC BATTERY SIMPLE            APARTMENT   False      True      08B
# 3                   SIMPLE            APARTMENT   False     False      08B
# 4           ARMED: HANDGUN             SIDEWALK   False     False        3
#
# ...

# %%
crime.groupby('Weekday')['ID'].count().plot(marker='o',label='Crimes')
plt.ylabel('No of Crimes')

plt.show()

# %%
sns.countplot(x='Primary Type',data=crime,order=crime['Primary Type'].value_counts().index)
plt.xticks(rotation='vertical')
plt.ylabel('No of Crimes')
plt.show()

# %%
temp=crime.groupby('Location Description')['ID'].count().sort_values(ascending=False)
temp=temp[:10]
temp
# Out:
# Location Description
# STREET                            178812
# RESIDENCE                         126027
# APARTMENT                          99501
# SIDEWALK                           70516
# OTHER                              31142
# PARKING LOT/GARAGE(NON.RESID.)     23555
# SMALL RETAIL STORE                 18650
# RESTAURANT                         18162
# RESIDENTIAL YARD (FRONT/BACK)      16350
# ALLEY                              15792
# Name: ID, dtype: int64

# %%
#Number of crimes in each location
temp.plot(kind='bar',color='green')
plt.ylabel('No of Crimes')
plt.show()

# %%
#Total Arrests whether made or not
sns.countplot(x='Arrest',data=crime)
plt.ylabel('No of Crimes')
plt.show()

# %%
#Arrests for each year
crime.groupby(['Year','Arrest'])['ID'].count().unstack().plot(kind='bar')
plt.ylabel('No of Crimes')
plt.show()

# %%
#Arrests were made or not for each crime
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Primary Type',hue='Arrest',data=crime,order=crime['Primary Type'].value_counts().index)
plt.xticks(rotation='vertical')
plt.ylabel('No of Crimes')
plt.show()

# %%
crime_theft=crime[(crime['Primary Type']=='THEFT')]

# %%
crime_theft.groupby([crime_theft['Date'].dt.month,'Primary Type'])['ID'].count().unstack().plot(marker='o')
plt.ylabel('No of Crimes')
plt.xlabel('Month')
plt.xticks(np.arange(13))
plt.show()

# %%
crime_battery=crime[(crime['Primary Type']=='BATTERY')]

# %%
crime_battery.groupby([crime_battery['Date'].dt.month,'Primary Type',])['ID'].count().unstack().plot(marker='o')
plt.ylabel('No of Crimes')
plt.xlabel('Month')
plt.xticks(np.arange(13))
plt.show()

# %%
crime_cdamage=crime[(crime['Primary Type']=='CRIMINAL DAMAGE')]

# %%
crime_cdamage.groupby([crime_cdamage['Date'].dt.month,'Primary Type',])['ID'].count().unstack().plot(marker='o')
plt.ylabel('No of Crimes')
plt.xlabel('Month')
plt.xticks(np.arange(13))
plt.show()

# %%
crime_assault=crime[(crime['Primary Type']=='ASSAULT')]

# %%
crime_assault.groupby([crime_assault['Date'].dt.month,'Primary Type',])['ID'].count().unstack().plot(marker='o')
plt.ylabel('No of Crimes')
plt.xlabel('Month')
plt.xticks(np.arange(13))
plt.show()

# %%
arrest=crime[crime['Arrest']==True]

# %%
# Graph between Arrests vs Crimes
arrest.groupby('Month')['ID'].count().plot(legend=True,label='Arrests',marker='o',figsize=(8,6))
crime.groupby('Month')['ID'].count().plot(legend=True,label='CrimeS',marker='o')
plt.ylabel('No of Crimes')
plt.xticks(np.arange(12),months)
plt.show()

# %%
#Analysing top 5 crimes
crime.groupby('Primary Type')['ID'].count().sort_values(ascending=False)
# Out:
# Primary Type
# THEFT                                181911
# BATTERY                              148834
# CRIMINAL DAMAGE                       88571
# ASSAULT                               56371
# OTHER OFFENSE                         50135
# DECEPTIVE PRACTICE                    46477
# NARCOTICS                             42891
# BURGLARY                              38796
# ROBBERY                               32593
# MOTOR VEHICLE THEFT                   31777
# CRIMINAL TRESPASS                     19906
# WEAPONS VIOLATION                     12193
# OFFENSE INVOLVING CHILDREN             6018
# PUBLIC PEACE VIOLATION                 5237
# CRIM SEXUAL ASSAULT                    4070
# INTERFERENCE WITH PUBLIC OFFICER       3379
# SEX OFFENSE                            2649
# PROSTITUTION                           2605
# ARSON                                  1281
# GAMBLING                                713
# LIQUOR LAW VIOLATION                    704
# ...

# %%
top_crime=crime[(crime['Primary Type']=='THEFT')|(crime['Primary Type']=='BATTERY')|(crime['Primary Type']=='CRIMINAL DAMAGE')|(crime['Primary Type']=='OTHER OFFENSE')|(crime['Primary Type']=='ASSAULT')]
top_crime
# Out:
#                ID                Date                                Block  \
# 0        10000092 2015-03-18 19:44:00                      047XX W OHIO ST
# 1        10000094 2015-03-18 23:00:00               066XX S MARSHFIELD AVE
# 2        10000095 2015-03-18 22:45:00                044XX S LAKE PARK AVE
# 3        10000096 2015-03-18 22:30:00                 051XX S MICHIGAN AVE
# 5        10000098 2015-03-18 22:00:00                  049XX S DREXEL BLVD
# 6        10000099 2015-03-18 23:00:00                    070XX S MORGAN ST
# 7        10000100 2015-03-18 21:35:00                  042XX S PRAIRIE AVE
# 9        10000104 2015-03-18 21:25:00                  097XX S PRAIRIE AVE
# 10       10000105 2015-03-18 21:30:00  130XX S DR MARTIN LUTHER KING JR DR
# 11       10000108 2015-03-15 16:10:00                078XX S VINCENNES AVE
# 13       10000110 2015-03-18 22:50:00                  014XX S ASHLAND AVE
# ...

# %%
temp=top_crime.pivot_table(values='ID', index='Month', columns='Year', aggfunc=np.size)

# %%
temp
# Out:
# Year      2015     2016     2017     2018
# Month
# Jan      847.0  12512.0   3465.0  12604.0
# Feb      721.0  11221.0   5999.0  11177.0
# Mar     6128.0  12769.0  12279.0  14041.0
# Apr    12986.0  12515.0  13278.0  14046.0
# May    14596.0  15447.0  14459.0  16759.0
# Jun    14038.0  14681.0  14841.0  15975.0
# Jul    14791.0  15268.0  15363.0   1056.0
# Aug    14980.0  15286.0  15135.0      NaN
# Sep    13715.0  14467.0  14020.0      NaN
# Oct    13413.0  14423.0  13196.0      NaN
# Nov    11982.0  12984.0  11841.0      NaN
# Dec    12429.0  10889.0  13200.0      NaN

# %%
sns.heatmap(temp)
plt.show()

# %%
top_crime.groupby(['Month','Year'])['ID'].count().unstack().plot(marker='o')
plt.xticks(np.arange(12),months)
plt.ylabel('No of Crimes')
plt.show()

# %%
temp= top_crime.pivot_table(values='ID', index='Primary Type',columns=top_crime['Date'].dt.hour, aggfunc=np.size)
sns.heatmap(temp)
plt.xlabel('Hours of the day')
plt.ylabel('Type of Crime')
plt.show()

# %%
top_crime.groupby([top_crime['Date'].dt.hour,'Primary Type',])['ID'].count().unstack().plot(marker='o')
plt.ylabel('No of Crimes')
plt.xlabel('Hours of the day')
plt.xticks(np.arange(24))
plt.show()

# %%
temp= top_crime.pivot_table(values='ID', index='Primary Type', columns='Month', aggfunc=np.size)
temp
# Out:
# Month              Jan   Feb    Mar    Apr    May    Jun    Jul    Aug    Sep  \
# Primary Type
# ASSAULT           2981  3192   4979   5786   7019   6721   4868   4694   4621
# BATTERY           8148  8172  12895  14977  18340  17528  13248  12553  11954
# CRIMINAL DAMAGE   4870  4709   7701   8963  10075   9602   8090   7698   7173
# OTHER OFFENSE     3034  3153   4826   5471   5976   5330   4211   4105   3581
# THEFT            10395  9892  14816  17628  19851  20354  16061  16351  14873
#
# Month              Oct    Nov    Dec
# Primary Type
# ASSAULT           4251   3723   3536
# BATTERY          11323   9882   9814
# CRIMINAL DAMAGE   7003   6537   6150
# OTHER OFFENSE     3728   3309   3411
# THEFT            14727  13356  13607

# %%
#sns.pairplot(crime,hue='Primary Type',palette='Set1')

# %%
top_crime
# Out:
#                ID                Date                                Block  \
# 0        10000092 2015-03-18 19:44:00                      047XX W OHIO ST
# 1        10000094 2015-03-18 23:00:00               066XX S MARSHFIELD AVE
# 2        10000095 2015-03-18 22:45:00                044XX S LAKE PARK AVE
# 3        10000096 2015-03-18 22:30:00                 051XX S MICHIGAN AVE
# 5        10000098 2015-03-18 22:00:00                  049XX S DREXEL BLVD
# 6        10000099 2015-03-18 23:00:00                    070XX S MORGAN ST
# 7        10000100 2015-03-18 21:35:00                  042XX S PRAIRIE AVE
# 9        10000104 2015-03-18 21:25:00                  097XX S PRAIRIE AVE
# 10       10000105 2015-03-18 21:30:00  130XX S DR MARTIN LUTHER KING JR DR
# 11       10000108 2015-03-15 16:10:00                078XX S VINCENNES AVE
# 13       10000110 2015-03-18 22:50:00                  014XX S ASHLAND AVE
# ...

# %%
crime_boolean=top_crime[(top_crime['Primary Type']=='BATTERY')|(top_crime['Primary Type']=='THEFT')]
crime_boolean
# Out:
#                ID                Date                                Block  \
# 0        10000092 2015-03-18 19:44:00                      047XX W OHIO ST
# 2        10000095 2015-03-18 22:45:00                044XX S LAKE PARK AVE
# 3        10000096 2015-03-18 22:30:00                 051XX S MICHIGAN AVE
# 5        10000098 2015-03-18 22:00:00                  049XX S DREXEL BLVD
# 6        10000099 2015-03-18 23:00:00                    070XX S MORGAN ST
# 7        10000100 2015-03-18 21:35:00                  042XX S PRAIRIE AVE
# 9        10000104 2015-03-18 21:25:00                  097XX S PRAIRIE AVE
# 13       10000110 2015-03-18 22:50:00                  014XX S ASHLAND AVE
# 14       10000111 2015-03-18 22:31:00                  051XX W CHICAGO AVE
# 17       10000115 2015-03-18 21:00:00                  069XX S LOOMIS BLVD
# 19       10000117 2015-03-18 22:45:00                  087XX S KIMBARK AVE
# ...

# %%
crime_boolean=top_crime[['Primary Type','Arrest','Domestic']]
crime_boolean
# Out:
#             Primary Type  Arrest  Domestic
# 0                BATTERY   False     False
# 1          OTHER OFFENSE    True     False
# 2                BATTERY   False      True
# 3                BATTERY   False     False
# 5                BATTERY   False     False
# 6                BATTERY   False      True
# 7                BATTERY   False      True
# 9                BATTERY   False     False
# 10       CRIMINAL DAMAGE   False     False
# 11         OTHER OFFENSE   False      True
# 13               BATTERY   False     False
# 14                 THEFT    True     False
# 17                 THEFT   False     False
# 19                 THEFT   False     False
# 20                 THEFT    True     False
# 23               BATTERY   False     False
# 25               BATTERY    True      True
# 26               BATTERY    True      True
# 27               ASSAULT   False     False
# 28               BATTERY   False     False
# 29               BATTERY   False     False
# ...

# %%
crime_boolean[['Arrest', 'Domestic']] = crime_boolean[['Arrest', 'Domestic']].astype(int)
crime_boolean
# Out:
# C:\Users\Bharadwaj\Anaconda3\lib\site-packages\pandas\core\frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
#             Primary Type  Arrest  Domestic
# 0                BATTERY       0         0
# 1          OTHER OFFENSE       1         0
# 2                BATTERY       0         1
# 3                BATTERY       0         0
# 5                BATTERY       0         0
# 6                BATTERY       0         1
# 7                BATTERY       0         1
# 9                BATTERY       0         0
# 10       CRIMINAL DAMAGE       0         0
# 11         OTHER OFFENSE       0         1
# 13               BATTERY       0         0
# 14                 THEFT       1         0
# ...

# %%
crime_boolean1=crime_boolean[(crime_boolean['Primary Type']=='THEFT')|(crime['Primary Type']=='BATTERY')]
crime_boolean1
# Out:
# C:\Users\Bharadwaj\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         Primary Type  Arrest  Domestic
# 0            BATTERY       0         0
# 2            BATTERY       0         1
# 3            BATTERY       0         0
# 5            BATTERY       0         0
# 6            BATTERY       0         1
# 7            BATTERY       0         1
# 9            BATTERY       0         0
# 13           BATTERY       0         0
# 14             THEFT       1         0
# 17             THEFT       0         0
# 19             THEFT       0         0
# 20             THEFT       1         0
# 23           BATTERY       0         0
# 25           BATTERY       1         1
# 26           BATTERY       1         1
# 28           BATTERY       0         0
# 29           BATTERY       0         0
# 35           BATTERY       0         0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = crime_boolean1.drop('Primary Type',axis=1)
y = crime_boolean1['Primary Type']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=101)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
predictions=dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
# Out:
# [[21750 22864]
#  [ 1997 52613]]
#
#
#               precision    recall  f1-score   support
#
#      BATTERY       0.92      0.49      0.64     44614
#        THEFT       0.70      0.96      0.81     54610
#
#    micro avg       0.75      0.75      0.75     99224
#    macro avg       0.81      0.73      0.72     99224
# weighted avg       0.80      0.75      0.73     99224

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, predictions))
# Out:
# Accuracy: 0.7494456986213013

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=10)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test,rfc_pred))
# Out:
# [[21750 22864]
#  [ 1997 52613]]

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#      BATTERY       0.92      0.49      0.64     44614
#        THEFT       0.70      0.96      0.81     54610
#
#    micro avg       0.75      0.75      0.75     99224
#    macro avg       0.81      0.73      0.72     99224
# weighted avg       0.80      0.75      0.73     99224

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, rfc_pred))
# Out:
# Accuracy: 0.7494456986213013

# %%
crime_boolean2=crime_boolean[(crime_boolean['Primary Type']=='ASSAULT')|(crime['Primary Type']=='OTHER OFFENSE')]
crime_boolean2
# Out:
# C:\Users\Bharadwaj\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#           Primary Type  Arrest  Domestic
# 1        OTHER OFFENSE       1         0
# 11       OTHER OFFENSE       0         1
# 27             ASSAULT       0         0
# 54             ASSAULT       0         0
# 58             ASSAULT       1         0
# 60       OTHER OFFENSE       1         0
# 74       OTHER OFFENSE       0         0
# 78             ASSAULT       0         1
# 83             ASSAULT       0         0
# 94       OTHER OFFENSE       0         0
# 113            ASSAULT       0         0
# 117            ASSAULT       0         0
# 124            ASSAULT       0         0
# 128            ASSAULT       0         1
# 131      OTHER OFFENSE       0         1
# 143      OTHER OFFENSE       0         0
# 144            ASSAULT       0         1
# ...

# %%
X = crime_boolean2.drop('Primary Type',axis=1)
y = crime_boolean2['Primary Type']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=101)

# %%
dtree1 = DecisionTreeClassifier()

# %%
dtree1.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
predictions=dtree1.predict(X_test)

# %%
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
# Out:
# [[10752  6174]
#  [ 8011  7015]]
#
#
#                precision    recall  f1-score   support
#
#       ASSAULT       0.57      0.64      0.60     16926
# OTHER OFFENSE       0.53      0.47      0.50     15026
#
#     micro avg       0.56      0.56      0.56     31952
#     macro avg       0.55      0.55      0.55     31952
#  weighted avg       0.55      0.56      0.55     31952

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, predictions))
# Out:
# Accuracy: 0.5560528292438658

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test,rfc_pred))
# Out:
# [[10752  6174]
#  [ 8011  7015]]

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#                precision    recall  f1-score   support
#
#       ASSAULT       0.57      0.64      0.60     16926
# OTHER OFFENSE       0.53      0.47      0.50     15026
#
#     micro avg       0.56      0.56      0.56     31952
#     macro avg       0.55      0.55      0.55     31952
#  weighted avg       0.55      0.56      0.55     31952

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, rfc_pred))
# Out:
# Accuracy: 0.5560528292438658

# %%
acrime_boolean=crime_boolean[['Primary Type','Arrest']]
acrime_boolean=acrime_boolean[(crime_boolean['Primary Type']=='ASSAULT')|(crime['Primary Type']=='OTHER OFFENSE')]

acrime_boolean
# Out:
# C:\Users\Bharadwaj\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#           Primary Type  Arrest
# 1        OTHER OFFENSE       1
# 11       OTHER OFFENSE       0
# 27             ASSAULT       0
# 54             ASSAULT       0
# 58             ASSAULT       1
# 60       OTHER OFFENSE       1
# 74       OTHER OFFENSE       0
# 78             ASSAULT       0
# 83             ASSAULT       0
# 94       OTHER OFFENSE       0
# 113            ASSAULT       0
# 117            ASSAULT       0
# 124            ASSAULT       0
# 128            ASSAULT       0
# 131      OTHER OFFENSE       0
# 143      OTHER OFFENSE       0
# 144            ASSAULT       0
# 155      OTHER OFFENSE       0
# 158            ASSAULT       0
# 182      OTHER OFFENSE       1
# 184      OTHER OFFENSE       0
# 201            ASSAULT       0
# 215      OTHER OFFENSE       1
# 218      OTHER OFFENSE       1
# ...

# %%
X = acrime_boolean.drop('Primary Type',axis=1)
y = acrime_boolean['Primary Type']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=101)

# %%
adtree = DecisionTreeClassifier()

# %%
adtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
apredictions=adtree.predict(X_test)

# %%
print(confusion_matrix(y_test,apredictions))
print('\n')
print(classification_report(y_test,apredictions))
# Out:
# [[13642  3284]
#  [11569  3457]]
#
#
#                precision    recall  f1-score   support
#
#       ASSAULT       0.54      0.81      0.65     16926
# OTHER OFFENSE       0.51      0.23      0.32     15026
#
#     micro avg       0.54      0.54      0.54     31952
#     macro avg       0.53      0.52      0.48     31952
#  weighted avg       0.53      0.54      0.49     31952

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, apredictions))
# Out:
# Accuracy: 0.5351464697045568

# %%
rfc1 = RandomForestClassifier(n_estimators=10)

# %%
rfc1.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc1_pred=rfc1.predict(X_test)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, rfc1_pred))
# Out:
# Accuracy: 0.5351464697045568

# %%
import folium

# %%
crime_map = folium.Map(location=[41.891398, -87.744384],zoom_start=11)

# %%
c_map_district = cm.groupby('District').first().loc[:, ['Latitude', 'Longitude', 'Location Description', 'Arrest']]

# %%
for i in range(len(c_map_district)):
    lat = c_map_district.iloc[i][0]
    long = c_map_district.iloc[i][1]
    popup_text = """District : {}<br>
                Arrest : {}<br>
                Location Description : {}<br>"""
    popup_text = popup_text.format(c_map_district.index[i],c_map_district.iloc[i][-1],c_map_district.iloc[i][-2])
    folium.CircleMarker(location = [lat, long], popup= popup_text).add_to(crime_map)

# %%
crime_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
c_map_ca = cm.groupby('Primary Type').first().loc[:, ['Latitude', 'Longitude', 'Location Description', 'Arrest']]

# %%
for i in range(len(c_map_ca)):
    lat = c_map_ca.iloc[i][0]
    long = c_map_ca.iloc[i][1]
    popup_text = """Primary Type : {}<br>
                Arrest : {}<br>
                Location Description : {}<br>"""
    popup_text = popup_text.format(c_map_ca.index[i],c_map_ca.iloc[i][-1],c_map_ca.iloc[i][-2])
    folium.CircleMarker(location = [lat, long], popup= popup_text).add_to(crime_map)

# %%
crime_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
temp1=cm.groupby('Block')['ID'].count().sort_values(ascending=False)
temp1
# Out:
# Block
# 001XX N STATE ST                       2967
# 008XX N MICHIGAN AVE                   1649
# 100XX W OHARE ST                       1515
# 0000X N STATE ST                       1428
# 076XX S CICERO AVE                     1363
# 0000X W TERMINAL ST                    1337
# 0000X S STATE ST                       1026
# 006XX N MICHIGAN AVE                    891
# 033XX W FILLMORE ST                     821
# 064XX S DR MARTIN LUTHER KING JR DR     795
# 011XX S CANAL ST                        783
# 063XX S DR MARTIN LUTHER KING JR DR     724
# 083XX S STEWART AVE                     699
# 012XX S WABASH AVE                      687
# 075XX S STONY ISLAND AVE                677
# 038XX W ROOSEVELT RD                    675
# 071XX S JEFFERY BLVD                    668
# 0000X W HUBBARD ST                      663
# 001XX W 87TH ST                         661
# 005XX N MICHIGAN AVE                    660
# 007XX N MICHIGAN AVE                    659
# ...
